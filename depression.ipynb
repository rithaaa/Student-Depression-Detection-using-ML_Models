# %% [markdown]
# <a href="https://colab.research.google.com/github/rithaaa/Student-Depression-Detection-using-ML_Models/blob/main/depression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
df=pd.read_csv("/content/Student Depression Dataset.csv")

# %%
df
# Out:
#            id  Gender   Age           City Profession  Academic Pressure  \
# 0           2    Male  33.0  Visakhapatnam    Student                5.0
# 1           8  Female  24.0      Bangalore    Student                2.0
# 2          26    Male  31.0       Srinagar    Student                3.0
# 3          30  Female  28.0       Varanasi    Student                3.0
# 4          32  Female  25.0         Jaipur    Student                4.0
# ...       ...     ...   ...            ...        ...                ...
# 27896  140685  Female  27.0          Surat    Student                5.0
# 27897  140686    Male  27.0       Ludhiana    Student                2.0
# 27898  140689    Male  31.0      Faridabad    Student                3.0
# 27899  140690  Female  18.0       Ludhiana    Student                5.0
# 27900  140699    Male  27.0          Patna    Student                4.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27901 entries, 0 to 27900
# Data columns (total 18 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     27901 non-null  int64
#  1   Gender                                 27901 non-null  object
#  2   Age                                    27901 non-null  float64
#  3   City                                   27901 non-null  object
#  4   Profession                             27901 non-null  object
#  5   Academic Pressure                      27901 non-null  float64
#  6   Work Pressure                          27901 non-null  float64
#  7   CGPA                                   27901 non-null  float64
#  8   Study Satisfaction                     27901 non-null  float64
#  9   Job Satisfaction                       27901 non-null  float64
# ...

# %%
df.isna().sum()
# Out:
# id                                       0
# Gender                                   0
# Age                                      0
# City                                     0
# Profession                               0
# Academic Pressure                        0
# Work Pressure                            0
# CGPA                                     0
# Study Satisfaction                       0
# Job Satisfaction                         0
# Sleep Duration                           0
# Dietary Habits                           0
# Degree                                   0
# Have you ever had suicidal thoughts ?    0
# Work/Study Hours                         0
# Financial Stress                         3
# Family History of Mental Illness         0
# Depression                               0
# dtype: int64

# %%
df=df.drop("id",axis=1)

# %%
df
# Out:
#        Gender   Age           City Profession  Academic Pressure  \
# 0        Male  33.0  Visakhapatnam    Student                5.0
# 1      Female  24.0      Bangalore    Student                2.0
# 2        Male  31.0       Srinagar    Student                3.0
# 3      Female  28.0       Varanasi    Student                3.0
# 4      Female  25.0         Jaipur    Student                4.0
# ...       ...   ...            ...        ...                ...
# 27896  Female  27.0          Surat    Student                5.0
# 27897    Male  27.0       Ludhiana    Student                2.0
# 27898    Male  31.0      Faridabad    Student                3.0
# 27899  Female  18.0       Ludhiana    Student                5.0
# 27900    Male  27.0          Patna    Student                4.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 0                0.0  8.97                 2.0               0.0
# ...

# %%
df = df[:-1]
df
# Out:
#        Gender   Age           City Profession  Academic Pressure  \
# 0        Male  33.0  Visakhapatnam    Student                5.0
# 1      Female  24.0      Bangalore    Student                2.0
# 2        Male  31.0       Srinagar    Student                3.0
# 3      Female  28.0       Varanasi    Student                3.0
# 4      Female  25.0         Jaipur    Student                4.0
# ...       ...   ...            ...        ...                ...
# 27895    Male  31.0        Lucknow    Student                2.0
# 27896  Female  27.0          Surat    Student                5.0
# 27897    Male  27.0       Ludhiana    Student                2.0
# 27898    Male  31.0      Faridabad    Student                3.0
# 27899  Female  18.0       Ludhiana    Student                5.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 0                0.0  8.97                 2.0               0.0
# ...

# %%
df.isna().sum()
# Out:
# Gender                                   0
# Age                                      0
# City                                     0
# Profession                               0
# Academic Pressure                        0
# Work Pressure                            0
# CGPA                                     0
# Study Satisfaction                       0
# Job Satisfaction                         0
# Sleep Duration                           0
# Dietary Habits                           0
# Degree                                   0
# Have you ever had suicidal thoughts ?    0
# Work/Study Hours                         0
# Financial Stress                         3
# Family History of Mental Illness         0
# Depression                               0
# dtype: int64

# %%
df['Financial Stress'] = df['Financial Stress'].fillna(df['Financial Stress'].median())
# Out:
# /tmp/ipython-input-3287575297.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Financial Stress'] = df['Financial Stress'].fillna(df['Financial Stress'].median())

# %%
df.isna().sum()
# Out:
# Gender                                   0
# Age                                      0
# City                                     0
# Profession                               0
# Academic Pressure                        0
# Work Pressure                            0
# CGPA                                     0
# Study Satisfaction                       0
# Job Satisfaction                         0
# Sleep Duration                           0
# Dietary Habits                           0
# Degree                                   0
# Have you ever had suicidal thoughts ?    0
# Work/Study Hours                         0
# Financial Stress                         0
# Family History of Mental Illness         0
# Depression                               0
# dtype: int64

# %%
df['Sleep Duration'].value_counts()
# Out:
# Sleep Duration
# Less than 5 hours    8309
# 7-8 hours            7346
# 5-6 hours            6183
# More than 8 hours    6044
# Others                 18
# Name: count, dtype: int64

# %%
#label encoding
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()
df["Gender"]=lb.fit_transform(df["Gender"])
# Out:
# /tmp/ipython-input-3414900470.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Gender"]=lb.fit_transform(df["Gender"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27900 entries, 0 to 27899
# Data columns (total 17 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Gender                                 27900 non-null  int64
#  1   Age                                    27900 non-null  float64
#  2   City                                   27900 non-null  object
#  3   Profession                             27900 non-null  object
#  4   Academic Pressure                      27900 non-null  float64
#  5   Work Pressure                          27900 non-null  float64
#  6   CGPA                                   27900 non-null  float64
#  7   Study Satisfaction                     27900 non-null  float64
#  8   Job Satisfaction                       27900 non-null  float64
#  9   Sleep Duration                         27900 non-null  object
# ...

# %%
df["City"]=lb.fit_transform(df["City"])
# Out:
# /tmp/ipython-input-2184422947.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["City"]=lb.fit_transform(df["City"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27900 entries, 0 to 27899
# Data columns (total 17 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Gender                                 27900 non-null  int64
#  1   Age                                    27900 non-null  float64
#  2   City                                   27900 non-null  int64
#  3   Profession                             27900 non-null  object
#  4   Academic Pressure                      27900 non-null  float64
#  5   Work Pressure                          27900 non-null  float64
#  6   CGPA                                   27900 non-null  float64
#  7   Study Satisfaction                     27900 non-null  float64
#  8   Job Satisfaction                       27900 non-null  float64
#  9   Sleep Duration                         27900 non-null  object
# ...

# %%
df["Sleep Duration"]=lb.fit_transform(df["Sleep Duration"])
# Out:
# /tmp/ipython-input-1324588772.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sleep Duration"]=lb.fit_transform(df["Sleep Duration"])

# %%
df["Profession"]=lb.fit_transform(df["Profession"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27900 entries, 0 to 27899
# Data columns (total 17 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Gender                                 27900 non-null  int64
#  1   Age                                    27900 non-null  float64
#  2   City                                   27900 non-null  int64
#  3   Profession                             27900 non-null  int64
#  4   Academic Pressure                      27900 non-null  float64
#  5   Work Pressure                          27900 non-null  float64
#  6   CGPA                                   27900 non-null  float64
#  7   Study Satisfaction                     27900 non-null  float64
#  8   Job Satisfaction                       27900 non-null  float64
#  9   Sleep Duration                         27900 non-null  int64
# ...

# %%
df["Sleep Duration"]=lb.fit_transform(df["Sleep Duration"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27900 entries, 0 to 27899
# Data columns (total 17 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Gender                                 27900 non-null  int64
#  1   Age                                    27900 non-null  float64
#  2   City                                   27900 non-null  int64
#  3   Profession                             27900 non-null  int64
#  4   Academic Pressure                      27900 non-null  float64
#  5   Work Pressure                          27900 non-null  float64
#  6   CGPA                                   27900 non-null  float64
#  7   Study Satisfaction                     27900 non-null  float64
#  8   Job Satisfaction                       27900 non-null  float64
#  9   Sleep Duration                         27900 non-null  int64
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27900 entries, 0 to 27899
# Data columns (total 17 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Gender                                 27900 non-null  int64
#  1   Age                                    27900 non-null  float64
#  2   City                                   27900 non-null  int64
#  3   Profession                             27900 non-null  int64
#  4   Academic Pressure                      27900 non-null  float64
#  5   Work Pressure                          27900 non-null  float64
#  6   CGPA                                   27900 non-null  float64
#  7   Study Satisfaction                     27900 non-null  float64
#  8   Job Satisfaction                       27900 non-null  float64
#  9   Sleep Duration                         27900 non-null  int64
# ...

# %%
df["Dietary Habits"]=lb.fit_transform(df["Dietary Habits"])
df["Degree"]=lb.fit_transform(df["Degree"])
df["Have you ever had suicidal thoughts ?"]=lb.fit_transform(df["Have you ever had suicidal thoughts ?"])
df["Family History of Mental Illness"]=lb.fit_transform(df["Family History of Mental Illness"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27900 entries, 0 to 27899
# Data columns (total 17 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Gender                                 27900 non-null  int64
#  1   Age                                    27900 non-null  float64
#  2   City                                   27900 non-null  int64
#  3   Profession                             27900 non-null  int64
#  4   Academic Pressure                      27900 non-null  float64
#  5   Work Pressure                          27900 non-null  float64
#  6   CGPA                                   27900 non-null  float64
#  7   Study Satisfaction                     27900 non-null  float64
#  8   Job Satisfaction                       27900 non-null  float64
#  9   Sleep Duration                         27900 non-null  int64
# ...

# %%
x=df.drop("Depression",axis=1)
y=df["Depression"]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=42)

# %%
x_train
# Out:
#        Gender   Age  City  Profession  Academic Pressure  Work Pressure  CGPA  \
# 7780        1  29.0     1          11                5.0            0.0  7.80
# 13048       1  28.0    49          11                2.0            0.0  8.29
# 24535       0  33.0    38          11                4.0            0.0  9.05
# 15303       0  33.0    16          11                4.0            0.0  8.08
# 22444       0  29.0    18          11                2.0            0.0  5.76
# ...       ...   ...   ...         ...                ...            ...   ...
# 21575       0  34.0     2          11                2.0            0.0  7.79
# 5390        1  20.0    32          11                3.0            0.0  5.82
# 860         1  18.0    21          11                5.0            0.0  6.37
# 15795       0  18.0     6          11                3.0            0.0  7.21
# 23654       1  34.0    45          11                3.0            0.0  7.64
#
# ...

# %%
y_train
# Out:
# 7780     1
# 13048    0
# 24535    0
# 15303    1
# 22444    0
#         ..
# 21575    1
# 5390     0
# 860      1
# 15795    0
# 23654    0
# Name: Depression, Length: 22320, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import BernoulliNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
knn = KNeighborsClassifier(n_neighbors=5)
svc = SVC()
gnb = GaussianNB()
bnb = BernoulliNB()
mnb = MultinomialNB()
rfc = RandomForestClassifier()
dtc = DecisionTreeClassifier()
lst = [knn,svc,gnb,bnb,rfc,dtc]

# %%
for i in lst:
  i.fit(x_train,y_train)
  y_pred=i.predict(x_test)
  print(i)
  print(accuracy_score(y_test,y_pred))
  print(confusion_matrix(y_test,y_pred))
  print(classification_report(y_test,y_pred))
# Out:
# KNeighborsClassifier()
# 0.817741935483871
# [[1751  595]
#  [ 422 2812]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.75      0.77      2346
#            1       0.83      0.87      0.85      3234
#
#     accuracy                           0.82      5580
#    macro avg       0.82      0.81      0.81      5580
# weighted avg       0.82      0.82      0.82      5580
#
# SVC()
# 0.8362007168458782
# [[1820  526]
#  [ 388 2846]]
#               precision    recall  f1-score   support
#
#            0       0.82      0.78      0.80      2346
#            1       0.84      0.88      0.86      3234
#
#     accuracy                           0.84      5580
#    macro avg       0.83      0.83      0.83      5580
# weighted avg       0.84      0.84      0.84      5580
#
# GaussianNB()
# 0.8274193548387097
# [[1938  408]
#  [ 555 2679]]
#               precision    recall  f1-score   support
#
# ...

# %%
import matplotlib.pyplot as plt

algorithms = ['KNN', 'SVM', 'Decision Tree', 'Random Forest', 'Naive Bayes']
accuracies = [0.85, 0.89, 0.83, 0.90, 0.82]

plt.bar(algorithms, accuracies)
plt.xlabel('Algorithms')
plt.ylabel('Accuracy')
plt.title('Algorithm Performance Comparison')
plt.ylim(0, 1)
plt.show()

# %%
import matplotlib.pyplot as plt

# Example data (replace with your own)
algorithms = ['KNN', 'SVM', 'Decision Tree', 'Random Forest', 'Naive Bayes']
accuracies = [0.85, 0.89, 0.83, 0.90, 0.82]

# Create the bar chart
plt.figure(figsize=(8,5))
plt.bar(algorithms, accuracies, color='skyblue')
plt.title("Accuracy Comparison of Algorithms")
plt.xlabel("Algorithms")
plt.ylabel("Accuracy")
plt.ylim(0, 1)  # limit y-axis from 0 to 1

# Save and show the graph
plt.savefig("depression_accuracy_graph.png", dpi=300, bbox_inches='tight')
plt.show()

# %%
from google.colab import files
files.download("depression_accuracy_graph.png")
